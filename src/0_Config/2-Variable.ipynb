# %%
# # Environment variables
# import os
# var_environment = os.getenv('environment')
# var_data_lake_name = os.getenv('abfss_data_lake')
# var_workflow_url = os.getenv('workflow_url')
# var_databricks_url = os.getenv('databricks_url')
# var_dev = f'abfss://landing@adlsprofarmadev.dfs.core.windows.net'
# var_landing = f'abfss://landing@{var_data_lake_name}.dfs.core.windows.net'
# var_bronze = f'abfss://bronze@{var_data_lake_name}.dfs.core.windows.net'
# var_silver = f'abfss://silver@{var_data_lake_name}.dfs.core.windows.net'
# var_gold = f'abfss://gold@{var_data_lake_name}.dfs.core.windows.net'
# var_platinum = f'abfss://platinum@{var_data_lake_name}.dfs.core.windows.net'
# var_controller = f'abfss://controller@{var_data_lake_name}.dfs.core.windows.net'
# var_sandbox = f'abfss://sandbox@{var_data_lake_name}.dfs.core.windows.net'
# var_secret_datalake = dbutils.secrets.get(scope="databricks-scope", key="secret-databricks-token")
# var_bronze_schema = 'bronze'
# var_silver_schema = 'silver'
# var_gold_schema = 'gold'
# var_platinum_schema = 'platinum'
# var_sandbox_schema = 'sandbox'
# var_teams = dbutils.secrets.get(scope="databricks-scope", key="secret-webhook-datastrategy")

# %%
# Environment variables
import os
var_environment = 'case_databricks' ## os.getenv('environment') DEV/QA/PROD
# var_data_lake_name = os.getenv('abfss_data_lake')
var_workflow_url = 'https://dbc-64ebbc15-54d1.cloud.databricks.com/'
# var_databricks_url = os.getenv('databricks_url')
# var_dev = f'abfss://landing@adlsprofarmadev.dfs.core.windows.net'
var_landing = f'/Volumes/case_databricks/landing/volume_landing'
var_bronze = f'/Volumes/case_databricks/bronze/volume_bronze'
var_silver = f'/Volumes/case_databricks/silver/volume_silver'
var_gold = f'/Volumes/case_databricks/gold/volume_gold'
var_platinum = f'/Volumes/case_databricks/platinum/volume_platinum'
# var_controller = f'abfss://controller@{var_data_lake_name}.dfs.core.windows.net'
# var_sandbox = f'abfss://sandbox@{var_data_lake_name}.dfs.core.windows.net'
# var_secret_datalake = dbutils.secrets.get(scope="databricks-scope", key="secret-databricks-token")
var_bronze_schema = 'bronze'
var_silver_schema = 'silver'
var_gold_schema = 'gold'
var_platinum_schema = 'platinum'
var_sandbox_schema = 'sandbox'
# var_teams = dbutils.secrets.get(scope="databricks-scope", key="secret-webhook-datastrategy")
var_teams = ""

# %%
display({
    "Environment Variables Documentation": {
        "Environment": f"var_environment: {var_environment}",
        # "Data Lake Name": "var_data_lake_name está comentada",
        # "Workflow URL Job run": "var_workflow_url está comentada",
        # "Databricks URL": "var_databricks_url está comentada",
        # "Var dev": "var_dev está comentada",
        "Landing Path": f"var_landing: {var_landing}",
        "Bronze Path": f"var_bronze: {var_bronze}",
        "Silver Path": f"var_silver: {var_silver}",
        "Gold Path": f"var_gold: {var_gold}",
        "Platinum Path" : f"var_platinum: {var_platinum}",
        # "Controller Path": "var_controller está comentada",
        # "Secret Data Lake Token": "var_secret_datalake está comentada",
        "Bronze Schema": f"var_bronze_schema: {var_bronze_schema}",
        "Silver Schema": f"var_silver_schema: {var_silver_schema}",
        "Gold Schema": f"var_gold_schema: {var_gold_schema}",
        "Platinum Schema": f"var_platinum_schema: {var_platinum_schema}",
        # "URL Teams": "var_teams está comentada"
    }
})
